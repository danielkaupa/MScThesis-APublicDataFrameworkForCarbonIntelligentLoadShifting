# %% [markdown]
# # Optimising Demand Response Strategies for Carbon Intelligent Load Shifting

# %% [markdown]
# # Investigating Data Size and Types

# %% [markdown]
# **NOTEBOOK PURPOSE(S):**
# * Explore methods for reducing the overall size of data used in this project, as well as more efficient methods of operating on the data.
#
# **NOTEBOOK OUTPUTS:**
# * N/A testing only - all temporaryoutputs should be deleted by running the appropriate cells

# %% [markdown]
# A note on measuring memory usage
#
# In reviewing how exactly to measure memory usage and process usage, I consulted the following resources:
# * https://psutil.readthedocs.io/en/latest/
# * https://docs.python.org/3/library/tracemalloc.html
# * https://pythonspeed.com/articles/measuring-memory-python/
# * https://www.geeksforgeeks.org/python/monitoring-memory-usage-of-a-running-python-program/
# * https://techkoalainsights.com/7-advanced-python-memory-profiling-techniques-for-production-debugging-beyond-basic-tools-cfe90589333f

# %% [markdown]
# ### Importing Libraries

# %%
# %matplotlib inline

# ────────────────────────────────────────────────────────────────────────────
# Data Manipulation & Analysis
# ─────────────────────────────────────────────────────────────────────────────
import pandas as pd
import polars as pl

# ─────────────────────────────────────────────────────────────────────────────
# Geospatial Data Handling
# ─────────────────────────────────────────────────────────────────────────────
from shapely.wkb import loads

# ─────────────────────────────────────────────────────────────────────────────
# Notebook/Display Tools
# ─────────────────────────────────────────────────────────────────────────────
from IPython.display import display

# ─────────────────────────────────────────────────────────────────────────────
# System / Miscellaneous
# ─────────────────────────────────────────────────────────────────────────────
import os
import binascii
import time
import tracemalloc
import psutil

# %% [markdown]
# ## Loading Data from Local Storage

# %%
root_directory = os.path.join('..', '..')
base_data_directory = os.path.join(root_directory, "data")
hitachi_data_directory = os.path.join(base_data_directory, 'hitachi')
meter_reading_directory = os.path.join(hitachi_data_directory, "meter_primary_files")  # Directory for meter readings

print("\n" + "-" * 120)
print(f"Contents of '{base_data_directory}' and subdirectories:\n" + "-" * 120)
for root, dirs, files in os.walk(base_data_directory):

    dirs.sort()  # Sort directories for consistent output
    files.sort()  # Sort files for consistent output

    for f in files:
        rel_dir = os.path.relpath(root, base_data_directory)
        rel_file = os.path.join(rel_dir, f) if rel_dir != "." else f
        print(f"  - {rel_file}")
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# Contents of '../../data' and subdirectories:
# ------------------------------------------------------------------------------------------------------------------------
#   - .DS_Store
#   - era5/.DS_Store
#   - era5/grib_downloads/125ae282169904325e8bc153160be150.grib
#   - era5/grib_downloads/125ae282169904325e8bc153160be150.grib.47d85.idx
#   - era5/grib_downloads/289f2aac241f8a158ff074a66682452e.grib
#   - era5/grib_downloads/554832a6209258041784298e5401a7ab.grib
#   - era5/grib_downloads/5aee58993569287064988fbc8ad385dd.grib
#   - era5/grib_downloads/5bcc58c42bdde8ce6b147b00099404bc.grib
#   - era5/grib_downloads/ad36c26a5d6daae43c9aeab1747e078c.grib
#   - era5/grib_downloads/b4eac1bff8a020500806be638e9d4ab9.grib
#   - era5/grib_downloads/bc20f736fa82ab5167820d9116ab4859.grib
#   - era5/grib_downloads/c8a985ffc4908e6597c4498ff596cbad.grib
#   - era5/grib_downloads/d1313a3f750d6e7bd89dff34b112d8a8.grib
#   - era5/grib_downloads/de87f0d77e8aeed868c68ac0daae3dc9.grib
#   - era5/grib_downloads/e23fa435dfdf294eba51378e96410b31.grib
#   - era5/parquets/placeholder.txt
#   - era5/weights/delhi_hcc_nearest_s2d_weights.nc
#   - era5/weights/delhi_lcc_nearest_s2d_weights.nc
#   - era5/weights/delhi_mcc_nearest_s2d_weights.nc
#   - era5/weights/delhi_ssr_conservative_weights.nc
#   - era5/weights/delhi_ssrd_conservative_weights.nc
#   - era5/weights/delhi_t2m_bilinear_weights.nc
#   - era5/weights/delhi_tcc_nearest_s2d_weights.nc
#   - era5/weights/delhi_tp_conservative_weights.nc
#   - era5/weights/delhi_u10_bilinear_weights.nc
#   - era5/weights/delhi_v10_bilinear_weights.nc
#   - era5/weights/mumbai_hcc_nearest_s2d_weights.nc
#   - era5/weights/mumbai_lcc_nearest_s2d_weights.nc
#   - era5/weights/mumbai_mcc_nearest_s2d_weights.nc
#   - era5/weights/mumbai_ssr_conservative_weights.nc
#   - era5/weights/mumbai_ssrd_conservative_weights.nc
#   - era5/weights/mumbai_t2m_bilinear_weights.nc
#   - era5/weights/mumbai_tcc_nearest_s2d_weights.nc
#   - era5/weights/mumbai_tp_conservative_weights.nc
#   - era5/weights/mumbai_u10_bilinear_weights.nc
#   - era5/weights/mumbai_v10_bilinear_weights.nc
#   - hitachi/.DS_Store
#   - hitachi/customers_20250714_1401.parquet
#   - hitachi/grid_readings_20250714_1401.parquet
#   - hitachi/grid_readings_20250714_1401_processed.parquet
#   - hitachi/grid_readings_20250714_1401_processed_half_hourly.parquet
#   - hitachi/meter_readings_20250701_1318.parquet
#   - hitachi/weather_20250714_1401.parquet
#   - hitachi/weather_20250714_1401_processed.parquet
#   - hitachi/weather_and_grid_data_half-hourly_20250714_1401.parquet
#   - hitachi/weather_data_combined_20250714_1401.parquet
#   - hitachi/meter_primary_files/.DS_Store
#   - hitachi/meter_primary_files/meter_readings_2021_20250714_2015.parquet
#   - hitachi/meter_primary_files/meter_readings_2021_20250714_2015_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_2021_Q4_20250714_2015_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_2022_20250714_2324.parquet
#   - hitachi/meter_primary_files/meter_readings_2022_20250714_2324_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_2022_Q1_20250714_2324_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_2022_Q2_20250714_2324_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_2022_Q3_20250714_2324_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_2022_Q4_20250714_2324_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_2023_20250714_2039.parquet
#   - hitachi/meter_primary_files/meter_readings_2023_20250714_2039_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_2023_Q1_20250714_2039_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_all_years_20250714_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_delhi_2021_20250714_2015_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_delhi_2021_Q4_20250714_2015_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_delhi_2022_20250714_2324_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_delhi_2022_Q1_20250714_2324_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_delhi_2022_Q2_20250714_2324_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_delhi_2022_Q3_20250714_2324_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_mumbai_2022_20250714_2324_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_mumbai_2022_Q3_20250714_2324_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_mumbai_2022_Q4_20250714_2324_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_mumbai_2023_20250714_2039_formatted.parquet
#   - hitachi/meter_primary_files/meter_readings_mumbai_2023_Q1_20250714_2039_formatted.parquet
#   - marginal_emissions_development/.DS_Store
#   - marginal_emissions_development/marginal_emissions_estimation_20250714_1401_test_data.parquet
#   - marginal_emissions_development/marginal_emissions_estimation_20250714_1401_train_data.parquet
#   - marginal_emissions_development/marginal_emissions_estimation_20250714_1401_validation_data.parquet
#   - marginal_emissions_development/qgam_smooth_weather_tuning_results.csv
#   - marginal_emissions_development/qgam_smooth_weather_tuning_results2.csv
#   - marginal_emissions_development/logs/marginal_emissions_results.part000.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_index.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_median.part000.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_median_index.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part000.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part001.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part002.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part003.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part004.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part005.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part006.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part007.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part008.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part009.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part010.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part011.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part012.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part013.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part014.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part015.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part016.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part017.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part018.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part019.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part020.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part021.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part022.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part023.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part024.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part025.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part026.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part027.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part028.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part029.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part030.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part031.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part032.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part033.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part034.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part035.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part036.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part037.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part038.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part039.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part040.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part041.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part042.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part043.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part044.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part045.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part046.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part047.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part048.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part049.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part050.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part051.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part052.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part053.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part054.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part055.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part056.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part057.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part058.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part059.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part060.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part061.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part062.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part063.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part064.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part065.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part066.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part067.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part068.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part069.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part070.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part071.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part072.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part073.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part074.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part075.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part076.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part077.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part078.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part079.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part080.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part081.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part082.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part083.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part084.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part085.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part086.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part087.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part088.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part089.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part090.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part091.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part092.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part093.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part094.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part095.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part096.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part097.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part098.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part099.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part100.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part101.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part102.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part103.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part104.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part105.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part106.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part107.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part108.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part109.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part110.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part111.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part112.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part113.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part114.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part115.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part116.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part117.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part118.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part119.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part120.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part121.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part122.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part123.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part124.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part125.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part126.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part127.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part128.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part129.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part130.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part131.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part132.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part133.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part134.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part135.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part136.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part137.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part138.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part139.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part140.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part141.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part142.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part143.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part144.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part145.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part146.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part147.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part148.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part149.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part150.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part151.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part152.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part153.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part154.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part155.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part156.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part157.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part158.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part159.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part160.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part161.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part162.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part163.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part164.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part165.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part166.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part167.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part168.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part169.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part170.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part171.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part172.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part173.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part174.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part175.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part176.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part177.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part178.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part179.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part180.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part181.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part182.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part183.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part184.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part185.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part186.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part187.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part188.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part189.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part190.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part191.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part192.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part193.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part194.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part195.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part196.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part197.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part198.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part199.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part200.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part201.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part202.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part203.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part204.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part205.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part206.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part207.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part208.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part209.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part210.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part211.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part212.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part213.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part214.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part215.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part216.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part217.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part218.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part219.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part220.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part221.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part222.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part223.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part224.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part225.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part226.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part227.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part228.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part229.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part230.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part231.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part232.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part233.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part234.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part235.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part236.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part237.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part238.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part239.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part240.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part241.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part242.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part243.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part244.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part245.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part246.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part247.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part248.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part249.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part250.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part251.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part252.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part253.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part254.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part255.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part256.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part257.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part258.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part259.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part260.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part261.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part262.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part263.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part264.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part265.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part266.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part267.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part268.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part269.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part270.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part271.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part272.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part273.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part274.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part275.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part276.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part277.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part278.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part279.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part280.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part281.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part282.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part283.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part284.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part285.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part286.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part287.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part288.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part289.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part290.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part291.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part292.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part293.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part294.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part295.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part296.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part297.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part298.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part299.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part300.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part301.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part302.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part303.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part304.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part305.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part306.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part307.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part308.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part309.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part310.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part311.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part312.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part313.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part314.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part315.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part316.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part317.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part318.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part319.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part320.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part321.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part322.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part323.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part324.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part325.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part326.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part327.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part328.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part329.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part330.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part331.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part332.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part333.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part334.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part335.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part336.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part337.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part338.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part339.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part340.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part341.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part342.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part343.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part344.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part345.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part346.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part347.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part348.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part349.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part350.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part351.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part352.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part353.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part354.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part355.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part356.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part357.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part358.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part359.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part360.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part361.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part362.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part363.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part364.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part365.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part366.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part367.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part368.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part369.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part370.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part371.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part372.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part373.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part374.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part375.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part376.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part377.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part378.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part379.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part380.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part381.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part382.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part383.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part384.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part385.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part386.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part387.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part388.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part389.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part390.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part391.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part392.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part393.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part394.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part395.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part396.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part397.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part398.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part399.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part400.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part401.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part402.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part403.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part404.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile.part405.csv
#   - marginal_emissions_development/logs/marginal_emissions_results_quantile_index.csv
#   - marginal_emissions_development/logs/original_model_results_summary.parquet
#   - marginal_emissions_development/logs/qgam_smooth_weather_tuning_results.csv
#   - marginal_emissions_development/logs/qgam_smooth_weather_tuning_results2.csv
#   - marginal_emissions_development/results/.DS_Store
#   - marginal_emissions_development/results/original_quantile_bins_marginal_emissions_timeseries.parquet
#   - marginal_emissions_development/results/pyGAM_marginal_emissions_timeseries.parquet
#   - optimisation_development/.DS_Store
#   - optimisation_development/average_emissions_2022-05-04_to_2022-05-18.parquet
#   - optimisation_development/marginal_and_average_emissions_2022-05-04_to_2022-05-18.parquet
#   - optimisation_development/marginal_emissions_2022-05-04_to_2022-05-18.parquet
#   - optimisation_development/meter_readings_2022-05-01_to_2022-05-14.parquet
#   - optimisation_development/meter_readings_2022-05-01_to_2022-05-14_with_marginal_emissions.parquet
#   - optimisation_development/meter_readings_2022-05-04_to_2022-05-18.parquet
#   - optimisation_development/meter_readings_all_years_20250714_formatted_with_emission_factors_filled.parquet
#   - optimisation_development/meter_readings_all_years_20250714_formatted_with_emission_factors_filled_2022-05-04_to_2022-05-18.parquet
#   - optimisation_development/meter_readings_all_years_20250714_formatted_with_pygam_cal_emission_factors_filled.parquet
#   - optimisation_development/meter_readings_all_years_20250714_formatted_with_pygam_emission_factors_filled.parquet
#   - optimisation_development/meter_readings_all_years_20250714_formatted_with_quantile_emission_factors_filled.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2021-11-28.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2021-12-05.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2021-12-12.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2021-12-19.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2021-12-26.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-01-02.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-01-09.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-01-16.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-01-23.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-01-30.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-02-06.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-02-13.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-02-20.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-02-27.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-03-06.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-03-13.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-03-20.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-03-27.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-04-10.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-04-17.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-04-24.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-05-01.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-05-08.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-05-15.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-05-22.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-05-29.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-06-05.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-06-12.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-06-26.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-07-03.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-07-10.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-07-17.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-07-24.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-07-31.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-08-07.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-08-14.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-08-21.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-08-28.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-09-04.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-09-11.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-09-18.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-09-25.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-10-02.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-10-09.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-10-16.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-10-23.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-10-30.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-11-06.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-11-13.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-11-20.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-11-27.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-12-04.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-12-11.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-12-18.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_delhi_week_2022-12-25.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2022-09-25.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2022-10-02.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2022-10-09.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2022-10-16.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2022-10-23.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2022-10-30.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2022-11-06.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2022-11-13.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2022-11-20.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2022-11-27.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2022-12-04.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2022-12-11.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2022-12-18.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2022-12-25.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2023-01-01.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2023-01-08.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2023-01-15.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2023-01-22.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2023-01-29.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2023-02-05.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2023-02-12.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2023-02-19.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2023-02-26.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2023-03-05.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2023-03-12.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2023-03-19.parquet
#   - optimisation_development/city_week_shards/meter_readings_20250714_emissions_mumbai_week_2023-03-26.parquet
#   - optimisation_development/full_results/.DS_Store
#   - optimisation_development/full_results/policy_2_greedy_metrics_20250828_203425.parquet
#   - optimisation_development/full_results/policy_2_greedy_metrics_multi_r0000.part001_20250828_111228.parquet
#   - optimisation_development/full_results/policy_2_greedy_moves_20250828_203425.parquet
#   - optimisation_development/full_results/policy_2_greedy_moves_multi_r0000.part001_20250828_111228.parquet
#   - optimisation_development/full_results/policy_2_greedy_optimised_20250828_203425.parquet
#   - optimisation_development/full_results/policy_2_greedy_optimised_multi_r0000.part001_20250828_111228.parquet
#   - optimisation_development/processing_files/.DS_Store
#   - optimisation_development/processing_files/average_emissions_2020-01-01_to_2025-06-04.parquet
#   - optimisation_development/processing_files/city_average_marginal_and_average_emissions_2021-01-01_to_2025-05-31.parquet
#   - optimisation_development/processing_files/customers_to_emission_factor_location_mapping.parquet
#   - optimisation_development/processing_files/marginal_and_average_emissions_2021-01-01_to_2025-05-31.parquet
#   - optimisation_development/processing_files/marginal_and_average_emissions_locations.parquet
#   - optimisation_development/processing_files/marginal_and_average_emissions_with_locations_2021-01-01_to_2025-05-31.parquet
#   - optimisation_development/processing_files/marginal_emissions_2021-01-01_to_2025-05-31.parquet
#   - optimisation_development/processing_files/meter_readings_all_years_20250714_formatted_with_emission_factor_location.parquet
#   - optimisation_development/processing_files/meter_readings_all_years_20250714_formatted_with_emission_factors_raw.parquet
#   - optimisation_development/processing_files/meter_readings_all_years_20250714_household_floor_lookup.parquet
#   - optimisation_development/testing_results/.DS_Store
#   - optimisation_development/testing_results/metrics_config_policy_1_greedy20250818_0127.parquet
#   - optimisation_development/testing_results/moves_config_policy_1_greedy20250818_0127.parquet
#   - optimisation_development/testing_results/optimised_config_policy_1_greedy20250818_0127.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_metrics_r0000_20250819_215456.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_metrics_r0000_20250820_020725.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_metrics_r0000_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_metrics_r0001_20250819_215456.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_metrics_r0001_20250820_020725.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_metrics_r0001_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_metrics_r0002_20250819_215456.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_metrics_r0002_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_metrics_run020725_combined.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_metrics_run035359_combined.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_metrics_run215456_combined.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_moves_r0000_20250819_215456.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_moves_r0000_20250820_020725.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_moves_r0000_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_moves_r0001_20250819_215456.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_moves_r0001_20250820_020725.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_moves_r0001_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_moves_r0002_20250819_215456.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_moves_r0002_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_moves_run020725_combined.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_moves_run035359_combined.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_moves_run215456_combined.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_optimised_r0000_20250819_215456.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_optimised_r0000_20250820_020725.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_optimised_r0000_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_optimised_r0001_20250819_215456.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_optimised_r0001_20250820_020725.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_optimised_r0001_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_optimised_r0002_20250819_215456.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_optimised_r0002_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_optimised_run020725_combined.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_optimised_run035359_combined.parquet
#   - optimisation_development/testing_results/policy_1_continuous_slsqp_optimised_run215456_combined.parquet
#   - optimisation_development/testing_results/policy_1_continuous_solver_trust_constr_metrics_r0002_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_continuous_solver_trust_constr_metrics_run035359_combined.parquet
#   - optimisation_development/testing_results/policy_1_continuous_solver_trust_constr_moves_r0002_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_continuous_solver_trust_constr_moves_run035359_combined.parquet
#   - optimisation_development/testing_results/policy_1_continuous_solver_trust_constr_optimised_r0002_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_continuous_solver_trust_constr_optimised_run035359_combined.parquet
#   - optimisation_development/testing_results/policy_1_greedy_metrics_r0000_20250820_011342.parquet
#   - optimisation_development/testing_results/policy_1_greedy_metrics_r0000_20250820_020725.parquet
#   - optimisation_development/testing_results/policy_1_greedy_metrics_r0000_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_greedy_metrics_r0001_20250820_011342.parquet
#   - optimisation_development/testing_results/policy_1_greedy_metrics_r0001_20250820_020725.parquet
#   - optimisation_development/testing_results/policy_1_greedy_metrics_r0001_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_greedy_metrics_r0002_20250820_011342.parquet
#   - optimisation_development/testing_results/policy_1_greedy_metrics_r0002_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_greedy_metrics_run011342_combined.parquet
#   - optimisation_development/testing_results/policy_1_greedy_metrics_run020725_combined.parquet
#   - optimisation_development/testing_results/policy_1_greedy_metrics_run035359_combined.parquet
#   - optimisation_development/testing_results/policy_1_greedy_moves_r0000_20250820_011342.parquet
#   - optimisation_development/testing_results/policy_1_greedy_moves_r0000_20250820_020725.parquet
#   - optimisation_development/testing_results/policy_1_greedy_moves_r0000_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_greedy_moves_r0001_20250820_011342.parquet
#   - optimisation_development/testing_results/policy_1_greedy_moves_r0001_20250820_020725.parquet
#   - optimisation_development/testing_results/policy_1_greedy_moves_r0001_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_greedy_moves_r0002_20250820_011342.parquet
#   - optimisation_development/testing_results/policy_1_greedy_moves_r0002_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_greedy_moves_run011342_combined.parquet
#   - optimisation_development/testing_results/policy_1_greedy_moves_run020725_combined.parquet
#   - optimisation_development/testing_results/policy_1_greedy_moves_run035359_combined.parquet
#   - optimisation_development/testing_results/policy_1_greedy_optimised_r0000_20250820_011342.parquet
#   - optimisation_development/testing_results/policy_1_greedy_optimised_r0000_20250820_020725.parquet
#   - optimisation_development/testing_results/policy_1_greedy_optimised_r0000_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_greedy_optimised_r0001_20250820_011342.parquet
#   - optimisation_development/testing_results/policy_1_greedy_optimised_r0001_20250820_020725.parquet
#   - optimisation_development/testing_results/policy_1_greedy_optimised_r0001_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_greedy_optimised_r0002_20250820_011342.parquet
#   - optimisation_development/testing_results/policy_1_greedy_optimised_r0002_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_1_greedy_optimised_run011342_combined.parquet
#   - optimisation_development/testing_results/policy_1_greedy_optimised_run020725_combined.parquet
#   - optimisation_development/testing_results/policy_1_greedy_optimised_run035359_combined.parquet
#   - optimisation_development/testing_results/policy_2_greedy_metrics_r0002_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_2_greedy_metrics_run035359_combined.parquet
#   - optimisation_development/testing_results/policy_2_greedy_moves_r0002_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_2_greedy_moves_run035359_combined.parquet
#   - optimisation_development/testing_results/policy_2_greedy_optimised_r0002_20250820_035359.parquet
#   - optimisation_development/testing_results/policy_2_greedy_optimised_run035359_combined.parquet

# %%
# File names copied from the output of the above code block
# These are the files we will use to investigate the data size reduction.
customers_path = os.path.join(hitachi_data_directory, "customers_20250714_1401.parquet")
grid_readings_path = os.path.join(hitachi_data_directory, "grid_readings_20250714_1401.parquet")

# This file is quite large (~8 GB), so will be a good test case for large files
meter_readings_2021_path = os.path.join(meter_reading_directory, "meter_readings_2021_20250714_2015.parquet")
# This file is also large, but only ~250MB, so it will be a good test case for smaller files
meter_readings_2022_path = os.path.join(meter_reading_directory, "meter_readings_2022_20250714_2324.parquet")
weather_path = os.path.join(hitachi_data_directory, "weather_20250714_1401.parquet")

# %%
# Size of files on disk
print("\n" + "-" * 120)
print(f"Size of files on disk:\n" + "-" * 120)
print(f"\tCustomers table: {os.path.getsize(customers_path) / (1024 * 1024):,.2f} MB")
print(f"\tGrid readings table: {os.path.getsize(grid_readings_path) / (1024 * 1024):,.2f} MB")
print(f"\tMeter readings table 2021: {os.path.getsize(meter_readings_2021_path) / (1024 * 1024):,.2f} MB")
print(f"\tMeter readings table 2022: {os.path.getsize(meter_readings_2022_path) / (1024 * 1024):,.2f} MB")
print(f"\tWeather table: {os.path.getsize(weather_path) / (1024 * 1024):,.2f} MB")
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# Size of files on disk:
# ------------------------------------------------------------------------------------------------------------------------
# 	Customers table: 3.80 MB
# 	Grid readings table: 21.71 MB
# 	Meter readings table 2021: 2,080.60 MB
# 	Meter readings table 2022: 10,335.06 MB
# 	Weather table: 77.77 MB

# %% [markdown]
# We'll now load and analyse each dataset separately.
#
# The kernel may need to be restarted betweeen analyses as the datasets are so large.
#
# We will also attempt to time processing to see the impact of using polars' 'lazy' implementation.

# %% [markdown]
# ## Reducing Data Size

# %% [markdown]
# ### Helper Functions

# %%
def memory_usage_per_column(df: pl.DataFrame) -> pl.DataFrame:
    """
    Computes the memory usage per column in a Polars DataFrame.

    Parameters
    ----------
    df : pl.DataFrame
        The Polars DataFrame for which to compute memory usage.
    Returns
    -------
    pl.DataFrame
        A DataFrame with memory usage per column:
        - column:           column name
        - bytes:            memory usage in bytes
        - mb:               memory usage in megabytes
        - percent_of_total: percentage of total memory usage
    """
    if not isinstance(df, pl.DataFrame):
        raise TypeError("Input must be a Polars DataFrame")
    if df.is_empty():
        return pl.DataFrame(columns=["column", "bytes", "mb", "percent_of_total"])
    else:
        total_bytes = df.estimated_size()
        rows = []
        for col in df.columns:
            col_bytes = df[col].estimated_size()
            mb = col_bytes / (1024**2)
            pct = (col_bytes / total_bytes * 100) if total_bytes else 0.0
            rows.append((col, col_bytes, mb, pct))
        return pl.DataFrame(rows, schema=[
            "column", "bytes", "mb", "percent_of_total"
        ],
        orient="row").sort("bytes", descending=True)

# %%
def dataframe_summary(
        df: pl.DataFrame,
        name: str = None,
        filepath: str=None
) -> None:
    """
    Prints a three-part summary of a provided polars dataframe including
    Schema, Per-column memory usage, and the first 5 rows of data

    Parameters
    ----------
    df : pl.DataFrame
        The DataFrame to summarise
    name : str, optional
        An optional name for the DataFrame, which will be included in the title of the summary
    filepath : str, optional
        An optional file path to the DataFrame, which will used to display the size of the file on disk.
        If provided, the file size will be included in the summary.

    Returns
    -------
    None
        Prints the summary directly to the console.
    """
    if not isinstance(df, pl.DataFrame):
        raise TypeError("Input must be a Polars DataFrame")

    if df.is_empty():
        print("DataFrame is empty.")
        return

    title = f"DataFrame Summary{' — ' + name if name else ''} "
    print("\n" + "-" * 120)
    print(title + "\n" + "-"* 120)

    if filepath:
        file_size_disk_mb = os.path.getsize(filepath) / (1024 * 1024)
        print(f"\nFile size on disk: {file_size_disk_mb:,.2f} MB")

    file_size_mem_mb = df.estimated_size() / (1024 * 1024)
    print(f"\nEstimated size in memory: {file_size_mem_mb:,.2f} MB")

    print("\nPer-column memory usage:\n"+ "-" * 120)
    mem_df = memory_usage_per_column(df)
    # pretty-print the little table
    for row in mem_df.iter_rows(named=True):
        print(f"  • {row['column']:<15s} {row['mb']:6.2f} MB  ({row['percent_of_total']:5.1f}%)")

    print("\nSchema:\n" + "-" * 120)
    for col, dtype in df.schema.items():
        print(f"  • {col}: {dtype}")

    print("\nFirst 5 rows: \n" + "-" * 120)

    # redact id and location columns if present (id, ca_id, location, customer_longitude, customer_latitude) to preserve confidentiality
    redact_cols = ['id', 'ca_id', 'value', 'location', 'customer_longitude', 'customer_latitude']
    for col in redact_cols:
        if col in df.columns:
            df = df.drop(col)

    display(df.head(5))
    print("Note: id and location related columns are redacted here to preserve customer confidentiality")
    return None

# %%
def wkb_to_coords(hex_wkb: str):
    """
    Convert a hex WKB string to coordinates (x, y).
    Uses binascii to decode the hex string and shapely's load function to convert WKB to a Point object.

    Parameters:
    ----------
    hex_wkb : str
        Hexadecimal string representing the WKB (Well-Known Binary) format of a point.

    Returns:
    -------
    tuple
        A tuple containing the x and y coordinates of the point, or (None, None)
        if the conversion fails.
    """
    try:
        point = loads(binascii.unhexlify(hex_wkb))
        return point.x, point.y
    except Exception:
        return None, None

# %% [markdown]
# ##### Single Use Functions

# %%
def memory_usage_per_column_pd(df: pd.DataFrame) -> pd.DataFrame:
    """
    Computes the memory usage per column in a Pandas DataFrame.

    Parameters
    ----------
    df : pd.DataFrame
        The Pandas DataFrame for which to compute memory usage.

    Returns
    -------
    pd.DataFrame
        A DataFrame with memory usage per column:
        - column:           column name
        - bytes:            memory usage in bytes
        - mb:               memory usage in megabytes
        - percent_of_total: percentage of total memory usage
    """
    if not isinstance(df, pd.DataFrame):
        raise TypeError("Input must be a Pandas DataFrame")

    if df.empty:
        return pd.DataFrame(columns=["column", "bytes", "mb", "percent_of_total"])

    mem_usage = df.memory_usage(deep=True)
    total_bytes = mem_usage.sum()

    result = pd.DataFrame({
        "column": mem_usage.index,
        "bytes": mem_usage.values,
        "mb": mem_usage.values / (1024 ** 2),
        "percent_of_total": (mem_usage.values / total_bytes) * 100
    }).reset_index(drop=True)

    return result.sort_values("bytes", ascending=False)

# %%
def dataframe_summary_pd(
        df: pd.DataFrame,
        name: str = None,
        filepath: str = None
) -> None:
    """
    Prints a three-part summary of a provided pandas dataframe including
    Schema, Per-column memory usage, and the first 5 rows of data.

    Parameters
    ----------
    df : pd.DataFrame
        The DataFrame to summarize
    name : str, optional
        An optional name for the DataFrame
    filepath : str, optional
        An optional file path to include file size information

    Returns
    -------
    None
        Prints the summary to console
    """
    if not isinstance(df, pd.DataFrame):
        raise TypeError("Input must be a Pandas DataFrame")

    if df.empty:
        print("DataFrame is empty.")
        return

    title = f"DataFrame Summary{' — ' + name if name else ''} "
    print("\n" + "-" * 120)
    print(title + "\n" + "-"* 120)

    if filepath:
        file_size_disk_mb = os.path.getsize(filepath) / (1024 * 1024)
        print(f"\nFile size on disk: {file_size_disk_mb:,.2f} MB")

    file_size_mem_mb = df.memory_usage(deep=True).sum() / (1024 * 1024)
    print(f"\nEstimated size in memory: {file_size_mem_mb:,.2f} MB")

    print("\nPer-column memory usage:\n"+ "-" * 120)
    mem_df = memory_usage_per_column_pd(df)
    for _, row in mem_df.iterrows():
        print(f"  • {row['column']:<15s} {row['mb']:6.2f} MB  ({row['percent_of_total']:5.1f}%)")

    print("\nSchema:\n" + "-" * 120)
    for col, dtype in df.dtypes.items():
        print(f"  • {col}: {dtype}")

    print("\nFirst 5 rows: \n" + "-" * 120)

    # redact id and location columns if present (id, ca_id, location, customer_longitude, customer_latitude) to preserve confidentiality
    redact_cols = ['id', 'ca_id', 'value','location', 'customer_longitude', 'customer_latitude']
    for col in redact_cols:
        if col in df.columns:
            df = df.drop(columns=[col])
    print(df.head(5))
    print("Note: id and location related columns are redacted here to preserve customer confidentiality")
    return None

# %% [markdown]
# ### General Use of Parquet Files

# %% [markdown]
# Polars and Parquet were adopted from the onset of this analysis due to their superior performance with large datasets.
#
# Parquet works with a columnar binary format which compresses data (deduplicating repeated values), unlike CSV's which uses a row-based text format that ends up wasting space on delimiters, and also forces all data to be parsed as strings.
# As a result, parquet files load faster, take up less space on both disk and memory, and (as is shown later in this notebook), polars' lazy execution drastically reduces execution costs.
#
# Below, we demonstrate the advantage of Polars and Parquet files over Pandas and CSV.

# %%
t1 = time.time()
customers_table_pldf = pl.read_parquet(customers_path)
t2 = time.time()
print(f"Time to read customers parquet file with Polars: {t2 - t1:.2f} seconds")

test_customers_table_df = customers_table_pldf.to_pandas()

test_customers_table_filepath = os.path.join(hitachi_data_directory, "customers_20250714_1401.csv")

# including no index for comparability because polars parquet files do not retain them
test_customers_table_df.to_csv(test_customers_table_filepath, index=False)

print("\n")
t3 = time.time()
test_customers_table_df = pd.read_csv(test_customers_table_filepath)
t4 = time.time()
print(f"Time to read customers csv file with Pandas: {t4 - t3:.2f} seconds\n\n")

dataframe_summary(
    customers_table_pldf,
    name="Customers Table - Polars to Parquet",
    filepath=customers_path)


dataframe_summary_pd(
    test_customers_table_df,
    name="Customers Table - Pandas to CSV",
    filepath=os.path.join(hitachi_data_directory, "customers_20250714_1401.csv")
)
# Out:
# Time to read customers parquet file with Polars: 0.02 seconds
#
#
# Time to read customers csv file with Pandas: 0.14 seconds
#
#
#
# ------------------------------------------------------------------------------------------------------------------------
# DataFrame Summary — Customers Table - Polars to Parquet
# ------------------------------------------------------------------------------------------------------------------------
#
# File size on disk: 3.80 MB
#
# Estimated size in memory: 14.28 MB
#
# Per-column memory usage:
# ------------------------------------------------------------------------------------------------------------------------
#   • location         10.76 MB  ( 75.4%)
#   • id                2.40 MB  ( 16.8%)
#   • city              1.11 MB  (  7.8%)
#
# Schema:
# ------------------------------------------------------------------------------------------------------------------------
#   • id: String
#   • location: String
#   • city: String
#
# First 5 rows:
# ------------------------------------------------------------------------------------------------------------------------
# shape: (5, 1)
# ┌────────┐
# │ city   │
# │ ---    │
# │ str    │
# ╞════════╡
# │ mumbai │
# │ mumbai │
# │ mumbai │
# │ mumbai │
# │ mumbai │
# └────────┘
# Note: id and location related columns are redacted here to preserve customer confidentiality
#
# ------------------------------------------------------------------------------------------------------------------------
# DataFrame Summary — Customers Table - Pandas to CSV
# ------------------------------------------------------------------------------------------------------------------------
#
# File size on disk: 14.92 MB
#
# Estimated size in memory: 38.13 MB
#
# Per-column memory usage:
# ------------------------------------------------------------------------------------------------------------------------
#   • location         23.03 MB  ( 60.4%)
#   • city             13.38 MB  ( 35.1%)
#   • id                1.72 MB  (  4.5%)
#   • Index             0.00 MB  (  0.0%)
#
# Schema:
# ------------------------------------------------------------------------------------------------------------------------
#   • id: float64
#   • location: object
#   • city: object
#
# First 5 rows:
# ------------------------------------------------------------------------------------------------------------------------
#      city
# 0  mumbai
# 1  mumbai
# 2  mumbai
# 3  mumbai
# 4  mumbai
# Note: id and location related columns are redacted here to preserve customer confidentiality

# %%
# Deleting the CSV file as it was just for comparison purposes

new_filepath = os.path.join(hitachi_data_directory, "customers_20250714_1401.csv")

try:
    os.remove(new_filepath)
    print(f"Successfully deleted: {new_filepath}")
except FileNotFoundError:
    print(f"File does not exist: {new_filepath}")
except PermissionError:
    print(f"Permission denied: Cannot delete {new_filepath}")
except Exception as e:
    print(f"Error deleting file: {e}")
# Out:
# Successfully deleted: ../../data/hitachi/customers_20250714_1401.csv

# %% [markdown]
# ### Individual Files

# %% [markdown]
# #### Customers table [customers_table_pldf]

# %%
# Loading the dataframe
customers_table_pldf = pl.read_parquet(customers_path)

# %%
dataframe_summary(customers_table_pldf, name="Customers Table", filepath=customers_path)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# DataFrame Summary — Customers Table
# ------------------------------------------------------------------------------------------------------------------------
#
# File size on disk: 3.80 MB
#
# Estimated size in memory: 14.28 MB
#
# Per-column memory usage:
# ------------------------------------------------------------------------------------------------------------------------
#   • location         10.76 MB  ( 75.4%)
#   • id                2.40 MB  ( 16.8%)
#   • city              1.11 MB  (  7.8%)
#
# Schema:
# ------------------------------------------------------------------------------------------------------------------------
#   • id: String
#   • location: String
#   • city: String
#
# First 5 rows:
# ------------------------------------------------------------------------------------------------------------------------
# shape: (5, 1)
# ┌────────┐
# │ city   │
# │ ---    │
# │ str    │
# ╞════════╡
# │ mumbai │
# │ mumbai │
# │ mumbai │
# │ mumbai │
# │ mumbai │
# └────────┘
# Note: id and location related columns are redacted here to preserve customer confidentiality

# %% [markdown]
# Based on the above - all three values are currently stored as string, which is certainly not the most efficient form of storage.
# Lets consider the options.
#
# 1. For the id column, we could change the id to integer, although this is not good practice to store ids as integers. Also as it is only ~17% of the overall storage costs, this is something we can potentially deprioritise in favor of other reductions.
# 2. For the location column, this is stored as a very long string. The location information is essential, but it may not be entirely necessary to store as a string. We may look into storing as longitude and latitude coordinates.
# 3. For the city column, these are stored as strings, but are relatively short and so not taking up very much space.**NOTE:** <span style="color:#d62728"> The analysis noted here has been redacted. </span> We could potentially look into dropping this column or changing the type to boolean, categorical, or integer.

# %% [markdown]
# Since the location is the largest - lets start with this one.

# %% [markdown]
# ##### 'location'

# %% [markdown]
# Let's calculate the longitude and latitude for the location column, drop the long string value, and then experiment with the float64 v float32 datatypes

# %%
# Calculating longitude and latitude from the location column
# Method 1 - converting to pandas DataFrame, using lambda function

# Start memory tracing
proc = psutil.Process()
mem_before = proc.memory_info().rss
tracemalloc.start()

# Start timing the conversion
t0 = time.perf_counter()

# First, convert the Polars DataFrame to a Pandas DataFrame
customers_pddf = customers_table_pldf.to_pandas()

# Decode the 'location' hex values into latitude and longitude coordinates
# and add them as new columns 'lon' and 'lat' in both DataFrames
customers_pddf[["customer_longitude", "customer_latitude"]] = customers_pddf["location"].apply(
    lambda x: pd.Series(wkb_to_coords(x))
)

# Convert the Pandas DataFrame back to a Polars DataFrame
customers_table_pldf = pl.from_pandas(customers_pddf)

# Stop timer and memory tracing
t1 = time.perf_counter()
current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()
mem_after = proc.memory_info().rss

# create temporary file path for the updated customers table
customers_path_temp = customers_path.replace(".parquet", "_temp.parquet")
# Save the updated DataFrame to a new Parquet file
customers_table_pldf_copy = customers_table_pldf.drop("location")
customers_table_pldf_copy.write_parquet(customers_path_temp)

# Return stats
print(f"Time taken to convert 'location' to 'lon' and 'lat': {t1 - t0:.3f} seconds")
print(f"PyObject Memory usage [tracemalloc]: {current / (1024 * 1024):.2f} MB (peak: {peak / (1024 * 1024):.2f} MB)")
print(f"Total Physical Memory usage (RSS) [psutil]: {(mem_after - mem_before) / (2**20):.3f} MB")
dataframe_summary(customers_table_pldf_copy, name="Customers Table with Coordinates", filepath=customers_path_temp)
# Out:
# Time taken to convert 'location' to 'lon' and 'lat': 25.903 seconds
# PyObject Memory usage [tracemalloc]: 42.64 MB (peak: 636.23 MB)
# Total Physical Memory usage (RSS) [psutil]: 671.016 MB
#
# ------------------------------------------------------------------------------------------------------------------------
# DataFrame Summary — Customers Table with Coordinates
# ------------------------------------------------------------------------------------------------------------------------
#
# File size on disk: 3.69 MB
#
# Estimated size in memory: 6.96 MB
#
# Per-column memory usage:
# ------------------------------------------------------------------------------------------------------------------------
#   • id                2.40 MB  ( 34.5%)
#   • customer_longitude   1.72 MB  ( 24.7%)
#   • customer_latitude   1.72 MB  ( 24.7%)
#   • city              1.11 MB  ( 16.0%)
#
# Schema:
# ------------------------------------------------------------------------------------------------------------------------
#   • id: String
#   • city: String
#   • customer_longitude: Float64
#   • customer_latitude: Float64
#
# First 5 rows:
# ------------------------------------------------------------------------------------------------------------------------
# shape: (5, 1)
# ┌────────┐
# │ city   │
# │ ---    │
# │ str    │
# ╞════════╡
# │ mumbai │
# │ mumbai │
# │ mumbai │
# │ mumbai │
# │ mumbai │
# └────────┘
# Note: id and location related columns are redacted here to preserve customer confidentiality

# %%
# Method 2 - using Polars lazy API for better performance on large datasets
# We will time this execution to see how it compares to the previous method
# We will also monitor the memory usage of the DataFrame before and after the operation

# Start memory tracing
proc = psutil.Process()
mem_before = proc.memory_info().rss
tracemalloc.start()

# Start timing the conversion
t0 = time.perf_counter()
# build a lazy pipeline:
lf = (
    # scan the Parquet file
    pl.scan_parquet(customers_path)
    # map the 'location' column from hex WKB to coordinates
    .with_columns([
        pl.col("location")
          .map_elements(lambda h: wkb_to_coords(h)[0], return_dtype=pl.Float64)
          .alias("customer_longitude"),

        pl.col("location")
          .map_elements(lambda h: wkb_to_coords(h)[1], return_dtype=pl.Float64)
          .alias("customer_latitude"),
    ])
)
# execute, returning an eager DataFrame
df = lf.collect()

# Stop timer and memory tracing
t1 = time.perf_counter()
current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()
mem_after = proc.memory_info().rss


customers_path_temp_lf = customers_path.replace(".parquet", "_temp_lf.parquet")
customers_table_pldf_copy_lf = df.drop("location")
# Save the updated DataFrame to a new Parquet file
customers_table_pldf_copy_lf.write_parquet(customers_path_temp_lf)

# Return stats
print(f"Time taken to convert 'location' to 'lon' and 'lat': {t1 - t0:.3f} seconds")
print(f"PyObject Memory usage [tracemalloc]: {current / (1024 * 1024):.2f} MB (peak: {peak / (1024 * 1024):.2f} MB)")
print(f"Total Physical Memory usage (RSS) [psutil]: {(mem_after - mem_before) / (2**20):.3f} MB")

dataframe_summary(customers_table_pldf_copy_lf, name="Customers Table with Coordinates", filepath=customers_path_temp_lf)

# look at the how the lazyframe works
print(lf.explain())
# Out:
# Time taken to convert 'location' to 'lon' and 'lat': 8.998 seconds
# PyObject Memory usage [tracemalloc]: 0.13 MB (peak: 0.14 MB)
# Total Physical Memory usage (RSS) [psutil]: 24.391 MB
#
# ------------------------------------------------------------------------------------------------------------------------
# DataFrame Summary — Customers Table with Coordinates
# ------------------------------------------------------------------------------------------------------------------------
#
# File size on disk: 3.69 MB
#
# Estimated size in memory: 6.96 MB
#
# Per-column memory usage:
# ------------------------------------------------------------------------------------------------------------------------
#   • id                2.40 MB  ( 34.5%)
#   • customer_longitude   1.72 MB  ( 24.7%)
#   • customer_latitude   1.72 MB  ( 24.7%)
#   • city              1.11 MB  ( 16.0%)
#
# Schema:
# ------------------------------------------------------------------------------------------------------------------------
#   • id: String
#   • city: String
#   • customer_longitude: Float64
#   • customer_latitude: Float64
#
# First 5 rows:
# ------------------------------------------------------------------------------------------------------------------------
# shape: (5, 1)
# ┌────────┐
# │ city   │
# │ ---    │
# │ str    │
# ╞════════╡
# │ mumbai │
# │ mumbai │
# │ mumbai │
# │ mumbai │
# │ mumbai │
# └────────┘
# Note: id and location related columns are redacted here to preserve customer confidentiality
#  WITH_COLUMNS:
#  [col("location").map_list().alias("customer_longitude"), col("location").map_list().alias("customer_latitude")]
#   Parquet SCAN [../../data/hitachi/customers_20250714_1401.parquet] [id: 6324863072]
#   PROJECT */3 COLUMNS

# %%
print("Note: id and location related columns are redacted here to preserve customer confidentiality")
print(customers_table_pldf.select(pl.exclude("id", "location", "customer_longitude", "customer_latitude")).describe())
# Out:
# Note: id and location related columns are redacted here to preserve customer confidentiality
# shape: (9, 2)
# ┌────────────┬────────┐
# │ statistic  ┆ city   │
# │ ---        ┆ ---    │
# │ str        ┆ str    │
# ╞════════════╪════════╡
# │ count      ┆ 225683 │
# │ null_count ┆ 0      │
# │ mean       ┆ null   │
# │ std        ┆ null   │
# │ min        ┆ delhi  │
# │ 25%        ┆ null   │
# │ 50%        ┆ null   │
# │ 75%        ┆ null   │
# │ max        ┆ mumbai │
# └────────────┴────────┘

# %% [markdown]
# Based on the above we have determined two things:
# 1. It will be more efficient to store the customer location in two separate columns
# 2. It is significantly faster and much less memory intensive to use the lazy api in polars.
#
# Also, after looking a the range of values that we are left with in longitude and latitude (out to 6 decimal points), it would likely be safer to leave these columns as Float64 type to retain their precision. Float32 retains precision out to 7 decimal points, but we do not know if we will require further precision present in Float64 later on. Best to air on the side of caution, especially with this smaller file (now even moreso)
#
# The following article contains some information about the precision and significant digits of different data types: https://massedcompute.com/faq-answers/?question=How%20does%20float32%20precision%20compare%20to%20float64%20precision%20in%20terms%20of%20accuracy%20and%20speed%20for%20machine%20learning%20tasks?#:~:text=Accuracy%20Comparison&text=Float32%20offers%20about%207%20significant,numerical%20instability%20in%20edge%20cases.
#
# We'll apply the changes in full processing later on, for now lets clean up the extra files we just created.

# %%
# Removing the temporary files created during the process
try:
    os.remove(customers_path_temp)
    print(f"Successfully deleted: {customers_path_temp}")

except FileNotFoundError:
    print(f"File does not exist: {customers_path_temp}")

try:
    os.remove(customers_path_temp_lf)
    print(f"Successfully deleted: {customers_path_temp_lf}")

except FileNotFoundError:
    print(f"File does not exist: {customers_path_temp_lf}")
# Out:
# Successfully deleted: ../../data/hitachi/customers_20250714_1401_temp.parquet
# Successfully deleted: ../../data/hitachi/customers_20250714_1401_temp_lf.parquet

# %% [markdown]
# ##### 'city'

# %% [markdown]
# We'll now look and see if we can reduce the size of the city column.
#
# Since the lazy method proved to be more efficient, we'll continue with that.

# %%
# Dropping the modified columns
try:
    customers_table_pldf = customers_table_pldf.drop("customer_longitude", "customer_latitude")
except Exception as e:
    print(f"Error dropping columns: {e}")

# Display the first few rows of the DataFrame
print("Note: id and location related columns are redacted here to preserve customer confidentiality")
print(customers_table_pldf.head().drop("id", "location"))
# Out:
# Note: id and location related columns are redacted here to preserve customer confidentiality
# shape: (5, 1)
# ┌────────┐
# │ city   │
# │ ---    │
# │ str    │
# ╞════════╡
# │ mumbai │
# │ mumbai │
# │ mumbai │
# │ mumbai │
# │ mumbai │
# └────────┘

# %%
# Start memory tracing
proc = psutil.Process()
mem_before = proc.memory_info().rss
tracemalloc.start()

# Start timing the conversion
t0 = time.perf_counter()
# build a lazy pipeline:
lazy_frame = (
    # scan the Parquet file
    pl.scan_parquet(customers_path)
    # map the 'location' column from hex WKB to coordinates
    .with_columns([
        # converting to categorical data type
        pl.col("city").cast(pl.Categorical).alias("city_category"),
        # converting to boolean data type
        (pl.col("city")=="delhi").alias("city_is_delhi"),
        # converting to UInt8 data type - requires pass through of categorical data type
        pl.col("city").cast(pl.Categorical).cast(pl.UInt32).cast(pl.UInt8).alias("city_uint8"),
    ])
)
df = lazy_frame.collect()

# Stop timer and memory tracing
t1 = time.perf_counter()
current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()
mem_after = proc.memory_info().rss

# create temporary file path for the updated customers table
customers_path_city = customers_path.replace(".parquet", "_temp_city.parquet")
customers_table_pldf_city = df
# Save the updated DataFrame to a new Parquet file
customers_table_pldf_city.write_parquet(customers_path_city)

# Return stats
print(f"Time taken to convert 'city' to various datatypes: {t1 - t0:.2f} seconds")
print(f"PyObject Memory usage [tracemalloc]: {current / (1024 * 1024):.2f} MB (peak: {peak / (1024 * 1024):.2f} MB)")
print(f"Total Physical Memory usage (RSS) [psutil]: {(mem_after - mem_before) / (2**20):.3f} MB")

print("Note: id and location related columns are redacted here to preserve customer confidentiality")
dataframe_summary(customers_table_pldf_city, name="Customers Table with Varying 'city' datatypes", filepath=customers_path_city)
# Out:
# Time taken to convert 'city' to various datatypes: 0.02 seconds
# PyObject Memory usage [tracemalloc]: 0.00 MB (peak: 0.01 MB)
# Total Physical Memory usage (RSS) [psutil]: 30.812 MB
# Note: id and location related columns are redacted here to preserve customer confidentiality
#
# ------------------------------------------------------------------------------------------------------------------------
# DataFrame Summary — Customers Table with Varying 'city' datatypes
# ------------------------------------------------------------------------------------------------------------------------
#
# File size on disk: 3.80 MB
#
# Estimated size in memory: 15.38 MB
#
# Per-column memory usage:
# ------------------------------------------------------------------------------------------------------------------------
#   • location         10.76 MB  ( 70.0%)
#   • id                2.40 MB  ( 15.6%)
#   • city              1.11 MB  (  7.2%)
#   • city_category     0.86 MB  (  5.6%)
#   • city_uint8        0.22 MB  (  1.4%)
#   • city_is_delhi     0.03 MB  (  0.2%)
#
# Schema:
# ------------------------------------------------------------------------------------------------------------------------
#   • id: String
#   • location: String
#   • city: String
#   • city_category: Categorical(ordering='physical')
#   • city_is_delhi: Boolean
#   • city_uint8: UInt8
#
# First 5 rows:
# ------------------------------------------------------------------------------------------------------------------------
# shape: (5, 4)
# ┌────────┬───────────────┬───────────────┬────────────┐
# │ city   ┆ city_category ┆ city_is_delhi ┆ city_uint8 │
# │ ---    ┆ ---           ┆ ---           ┆ ---        │
# │ str    ┆ cat           ┆ bool          ┆ u8         │
# ╞════════╪═══════════════╪═══════════════╪════════════╡
# │ mumbai ┆ mumbai        ┆ false         ┆ 0          │
# │ mumbai ┆ mumbai        ┆ false         ┆ 0          │
# │ mumbai ┆ mumbai        ┆ false         ┆ 0          │
# │ mumbai ┆ mumbai        ┆ false         ┆ 0          │
# │ mumbai ┆ mumbai        ┆ false         ┆ 0          │
# └────────┴───────────────┴───────────────┴────────────┘
# Note: id and location related columns are redacted here to preserve customer confidentiality

# %%
# remove the temporary files created during the process
try:
    os.remove(customers_path_city)
    print(f"Successfully deleted: {customers_path_city}")
except FileNotFoundError:
    print(f"File does not exist: {customers_path_city}")
# Out:
# Successfully deleted: ../../data/hitachi/customers_20250714_1401_temp_city.parquet

# %% [markdown]
# Based on this - we'll likely store the city variable as categorical to retain the readability.
#
# But it is good to know that boolean is available and could still significantly reduce the file size if needed later

# %% [markdown]
# ##### Testing Implementation of Changes

# %% [markdown]
# Based on the contents of this article, I will continue to use the default 'snappy' compression, but also ensure to specify it for clarity
#
# https://dev.to/alexmercedcoder/all-about-parquet-part-05-compression-techniques-in-parquet-4bcb

# %%
# We will change the location to two separate columns for longitude and latitude
# We will also convert the 'city' column to a categorical data type for better memory efficiency.
# We will then drop the unnecessary columns, and save the DataFrame to a new Parquet file()

# We'll also monitor the memory usage and time taken for this operation
# Start memory tracing
proc = psutil.Process()
mem_before = proc.memory_info().rss
tracemalloc.start()
# Start timing the conversion
t0 = time.perf_counter()

customers_lazy_operations = (
    pl.scan_parquet(customers_path)
    .with_columns([
        # converting to two separate columns for longitude and latitude
        pl.col("location")
          .map_elements(lambda h: wkb_to_coords(h)[0], return_dtype=pl.Float64)
          .alias("customer_longitude"),
        pl.col("location")
          .map_elements(lambda h: wkb_to_coords(h)[1], return_dtype=pl.Float64)
          .alias("customer_latitude"),

        # converting 'city' column to categorical data type
        pl.col("city").cast(pl.Categorical),
    ])
    .drop("location")  # drop the original 'location' column
)

customers_table_optimised_pldf = customers_lazy_operations.collect()

# Stop timer and memory tracing
t1 = time.perf_counter()
current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()
mem_after = proc.memory_info().rss

# Return stats
print(f"Time taken to optimize 'location' and 'city' columns: {t1 - t0:.2f} seconds")
print(f"PyObject Memory usage [tracemalloc]: {current / (1024 * 1024):.2f} MB (peak: {peak / (1024 * 1024):.2f} MB)")
print(f"Total Physical Memory usage (RSS) [psutil]: {(mem_after - mem_before) / (2**20):.3f} MB")
# Out:
# Time taken to optimize 'location' and 'city' columns: 8.59 seconds
# PyObject Memory usage [tracemalloc]: 0.01 MB (peak: 0.02 MB)
# Total Physical Memory usage (RSS) [psutil]: 24.859 MB

# %%
# Save the modified DataFrame to a new Parquet file

# extracting base name
base, ext = os.path.splitext(customers_path)
customers_table_optimised_path = f"{base}_optimised{ext}"

# saving new dataframe
customers_table_optimised_pldf.write_parquet(
    customers_table_optimised_path,
    compression="snappy",  # Using snappy compression for better performance
    statistics=True,  # Enable statistics for better query performance (doesn't make a noticeable change on disk storage)
)

# %%
# View the difference between the original and optimized DataFrames
print("Note: id and location related columns are redacted here to preserve customer confidentiality")
dataframe_summary(customers_table_pldf, name="Original Customers Table", filepath=customers_path)
dataframe_summary(customers_table_optimised_pldf, name="Optimized Customers Table", filepath=customers_table_optimised_path)
# Out:
# Note: id and location related columns are redacted here to preserve customer confidentiality
#
# ------------------------------------------------------------------------------------------------------------------------
# DataFrame Summary — Original Customers Table
# ------------------------------------------------------------------------------------------------------------------------
#
# File size on disk: 3.80 MB
#
# Estimated size in memory: 14.28 MB
#
# Per-column memory usage:
# ------------------------------------------------------------------------------------------------------------------------
#   • location         10.76 MB  ( 75.4%)
#   • id                2.40 MB  ( 16.8%)
#   • city              1.11 MB  (  7.8%)
#
# Schema:
# ------------------------------------------------------------------------------------------------------------------------
#   • id: String
#   • location: String
#   • city: String
#
# First 5 rows:
# ------------------------------------------------------------------------------------------------------------------------
# shape: (5, 1)
# ┌────────┐
# │ city   │
# │ ---    │
# │ str    │
# ╞════════╡
# │ mumbai │
# │ mumbai │
# │ mumbai │
# │ mumbai │
# │ mumbai │
# └────────┘
# Note: id and location related columns are redacted here to preserve customer confidentiality
#
# ------------------------------------------------------------------------------------------------------------------------
# DataFrame Summary — Optimized Customers Table
# ------------------------------------------------------------------------------------------------------------------------
#
# File size on disk: 4.63 MB
#
# Estimated size in memory: 6.71 MB
#
# Per-column memory usage:
# ------------------------------------------------------------------------------------------------------------------------
#   • id                2.40 MB  ( 35.8%)
#   • customer_longitude   1.72 MB  ( 25.7%)
#   • customer_latitude   1.72 MB  ( 25.7%)
#   • city              0.86 MB  ( 12.8%)
#
# Schema:
# ------------------------------------------------------------------------------------------------------------------------
#   • id: String
#   • city: Categorical(ordering='physical')
#   • customer_longitude: Float64
#   • customer_latitude: Float64
#
# First 5 rows:
# ------------------------------------------------------------------------------------------------------------------------
# shape: (5, 1)
# ┌────────┐
# │ city   │
# │ ---    │
# │ cat    │
# ╞════════╡
# │ mumbai │
# │ mumbai │
# │ mumbai │
# │ mumbai │
# │ mumbai │
# └────────┘
# Note: id and location related columns are redacted here to preserve customer confidentiality

# %% [markdown]
# ---
#
# As we can see, the file size on disk may have increased slightly, but the file size in memory has been reduced by more than 50%.
#
# ---

# %%
# removing the temporary files created during the process
try:
    os.remove(customers_table_optimised_path)
    print(f"Successfully deleted: {customers_table_optimised_path}")
except FileNotFoundError:
    print(f"File does not exist: {customers_table_optimised_path}")
# Out:
# Successfully deleted: ../../data/hitachi/customers_20250714_1401_optimised.parquet

# %% [markdown]
# #### weather table [weather_table_pldf]

# %% [markdown]
# We now look at the weather table data.

# %%
# Loading the data
weather_table_pldf = pl.read_parquet(weather_path)

# %%
dataframe_summary(df=weather_table_pldf, name="Weather Table", filepath=weather_path)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# DataFrame Summary — Weather Table
# ------------------------------------------------------------------------------------------------------------------------
#
# File size on disk: 77.77 MB
#
# Estimated size in memory: 610.27 MB
#
# Per-column memory usage:
# ------------------------------------------------------------------------------------------------------------------------
#   • location        190.24 MB  ( 31.2%)
#   • wind_speed       61.35 MB  ( 10.1%)
#   • wind_direction   61.35 MB  ( 10.1%)
#   • temperature      61.35 MB  ( 10.1%)
#   • precipitation    61.35 MB  ( 10.1%)
#   • surface_net_solar_radiation  61.35 MB  ( 10.1%)
#   • surface_solar_radiation_downwards  61.35 MB  ( 10.1%)
#   • timestamp        30.44 MB  (  5.0%)
#   • city             21.47 MB  (  3.5%)
#
# Schema:
# ------------------------------------------------------------------------------------------------------------------------
#   • timestamp: Datetime(time_unit='us', time_zone=None)
#   • wind_speed: Decimal(precision=38, scale=18)
#   • wind_direction: Decimal(precision=38, scale=20)
#   • temperature: Decimal(precision=38, scale=15)
#   • city: String
#   • precipitation: Decimal(precision=38, scale=28)
#   • location: String
#   • surface_net_solar_radiation: Decimal(precision=38, scale=17)
#   • surface_solar_radiation_downwards: Decimal(precision=38, scale=17)
#
# First 5 rows:
# ------------------------------------------------------------------------------------------------------------------------
# shape: (5, 8)
# ┌────────────┬────────────┬────────────┬────────────┬───────┬────────────┬────────────┬────────────┐
# │ timestamp  ┆ wind_speed ┆ wind_direc ┆ temperatur ┆ city  ┆ precipitat ┆ surface_ne ┆ surface_so │
# │ ---        ┆ ---        ┆ tion       ┆ e          ┆ ---   ┆ ion        ┆ t_solar_ra ┆ lar_radiat │
# │ datetime[μ ┆ decimal[38 ┆ ---        ┆ ---        ┆ str   ┆ ---        ┆ diation    ┆ ion_downwa │
# │ s]         ┆ ,18]       ┆ decimal[38 ┆ decimal[38 ┆       ┆ decimal[38 ┆ ---        ┆ …          │
# │            ┆            ┆ ,20]       ┆ ,15]       ┆       ┆ ,28]       ┆ decimal[38 ┆ ---        │
# │            ┆            ┆            ┆            ┆       ┆            ┆ ,17]       ┆ decimal[38 │
# │            ┆            ┆            ┆            ┆       ┆            ┆            ┆ ,17]       │
# ╞════════════╪════════════╪════════════╪════════════╪═══════╪════════════╪════════════╪════════════╡
# │ 2024-12-13 ┆ 8.01357502 ┆ 105.092318 ┆ 15.9752197 ┆ delhi ┆ 0.00000000 ┆ 12296608.0 ┆ 14926616.0 │
# │ 13:00:00   ┆ 0999754000 ┆ 1186646500 ┆ 26562500   ┆       ┆ 0000000000 ┆ 0000000000 ┆ 0000000000 │
# │            ┆            ┆ 0000       ┆            ┆       ┆ 0000000000 ┆ 000000     ┆ 000000     │
# │ 2024-12-13 ┆ 8.28988395 ┆ 110.726143 ┆ 14.6460266 ┆ delhi ┆ 0.00000000 ┆ 12108108.0 ┆ 14736050.0 │
# │ 14:00:00   ┆ 7905610000 ┆ 2753614100 ┆ 11328125   ┆       ┆ 0000000000 ┆ 0000000000 ┆ 0000000000 │
# │            ┆            ┆ 0000       ┆            ┆       ┆ 0000000000 ┆ 000000     ┆ 000000     │
# │ 2024-12-13 ┆ 8.33689095 ┆ 110.277251 ┆ 14.6292419 ┆ delhi ┆ 0.00000000 ┆ 12149601.0 ┆ 14737817.0 │
# │ 14:00:00   ┆ 4411203000 ┆ 0258955400 ┆ 43359375   ┆       ┆ 0000000000 ┆ 0000000000 ┆ 0000000000 │
# │            ┆            ┆ 0000       ┆            ┆       ┆ 0000000000 ┆ 000000     ┆ 000000     │
# │ 2024-12-13 ┆ 8.40372646 ┆ 109.706665 ┆ 14.6237792 ┆ delhi ┆ 0.00000000 ┆ 12240716.0 ┆ 14738703.0 │
# │ 14:00:00   ┆ 8287198000 ┆ 5665699800 ┆ 96875000   ┆       ┆ 0000000000 ┆ 0000000000 ┆ 0000000000 │
# │            ┆            ┆ 0000       ┆            ┆       ┆ 0000000000 ┆ 000000     ┆ 000000     │
# │ 2024-12-13 ┆ 8.45463719 ┆ 109.043528 ┆ 14.6112976 ┆ delhi ┆ 0.00000000 ┆ 12278334.0 ┆ 14740205.0 │
# │ 14:00:00   ┆ 0808407000 ┆ 2144605200 ┆ 07421875   ┆       ┆ 0000000000 ┆ 0000000000 ┆ 0000000000 │
# │            ┆            ┆ 0000       ┆            ┆       ┆ 0000000000 ┆ 000000     ┆ 000000     │
# └────────────┴────────────┴────────────┴────────────┴───────┴────────────┴────────────┴────────────┘
# Note: id and location related columns are redacted here to preserve customer confidentiality

# %%
weather_table_pldf.describe()
# Out:
# shape: (9, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ timestamp ┆ wind_spee ┆ wind_dire ┆ … ┆ precipita ┆ location  ┆ surface_n ┆ surface_ │
# │ ---       ┆ ---       ┆ d         ┆ ction     ┆   ┆ tion      ┆ ---       ┆ et_solar_ ┆ solar_ra │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ str       ┆ radiation ┆ diation_ │
# │           ┆           ┆ f64       ┆ f64       ┆   ┆ f64       ┆           ┆ ---       ┆ downwa…  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ f64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 3989664   ┆ 2.046285e ┆ 2.046285e ┆ … ┆ 2.046285e ┆ 3989664   ┆ 1.889953e ┆ 1.889954 │
# │           ┆           ┆ 6         ┆ 6         ┆   ┆ 6         ┆           ┆ 6         ┆ e6       │
# │ null_coun ┆ 0         ┆ 1.943379e ┆ 1.943379e ┆ … ┆ 1.943379e ┆ 0         ┆ 2.099711e ┆ 2.09971e │
# │ t         ┆           ┆ 6         ┆ 6         ┆   ┆ 6         ┆           ┆ 6         ┆ 6        │
# │ mean      ┆ 2022-09-1 ┆ 5.913636  ┆ 167.30251 ┆ … ┆ 0.001737  ┆ null      ┆ 1.1276e7  ┆ 1.3538e7 │
# │           ┆ 5         ┆           ┆ 3         ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 12:30:00  ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ std       ┆ null      ┆ 3.125727  ┆ 88.154022 ┆ … ┆ 0.006866  ┆ null      ┆ 6.9285e6  ┆ 8.3022e6 │
# │ min       ┆ 2019-12-3 ┆ 0.005403  ┆ 0.000265  ┆ … ┆ 0.0       ┆ 010100002 ┆ 0.0       ┆ 0.0      │
# │           ┆ 1         ┆           ┆           ┆   ┆           ┆ 0E6100000 ┆           ┆          │
# │           ┆ 01:00:00  ┆           ┆           ┆   ┆           ┆ 14AE47E17 ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ A24…      ┆           ┆          │
# │ 25%       ┆ 2021-05-0 ┆ 3.790591  ┆ 106.34765 ┆ … ┆ 0.0       ┆ null      ┆ 5.062334e ┆ 6.017553 │
# │           ┆ 8         ┆           ┆ 1         ┆   ┆           ┆           ┆ 6         ┆ e6       │
# │           ┆ 19:00:00  ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 50%       ┆ 2022-09-1 ┆ 5.431484  ┆ 145.85406 ┆ … ┆ 0.000001  ┆ null      ┆ 1.2313436 ┆ 1.4862e7 │
# │           ┆ 5         ┆           ┆           ┆   ┆           ┆           ┆ e7        ┆          │
# │           ┆ 13:00:00  ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 75%       ┆ 2024-01-2 ┆ 7.45679   ┆ 241.90180 ┆ … ┆ 0.000466  ┆ null      ┆ 1.6668687 ┆ 1.991219 │
# │           ┆ 3         ┆           ┆ 7         ┆   ┆           ┆           ┆ e7        ┆ 6e7      │
# │           ┆ 06:00:00  ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ max       ┆ 2025-06-0 ┆ 42.517314 ┆ 359.99997 ┆ … ┆ 0.314005  ┆ 010100002 ┆ 2.49234e7 ┆ 2.903841 │
# │           ┆ 1         ┆           ┆ 9         ┆   ┆           ┆ 0E6100000 ┆           ┆ 4e7      │
# │           ┆ 00:00:00  ┆           ┆           ┆   ┆           ┆ F6285C8FC ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 255…      ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ---
#
# Though not a large file on the disk, this dataset takes up a comparatively large of memory (~8 times more than disk).
#
# Repeated variables:
# * 'location' - we have already seen this with the customer location data and know that it will likely reduce the size of the file to store this string value as individual longitude and latitude coordinates. We will double check this as well to be certain of its effectiveness.
# * 'city' - again, we have already seen this and know that we can change the datatype to categorical. It may not save a large amount of memory, but it is a reduction.
#
#
# New variables:
#
# * 'wind_direction' - wind direction is recorded in degrees ranging from 0 to 360. It is doubtful that a thousandth of a degree would make much of a difference in our analysis as we are not predicting the distance or location that a particle will move in the air. We will assume that we can safely drop this precision from its existing Decimal(38,18) down to Float32 datatype. This will retain precision 7 digits after the decimal.
# * 'wind_speed' - wind speed is also a variable whose extreme precision is unlikely to affect our analysis, so we will drop this to Float32 as well.
# * 'temperature' - is surface temperature measured in degrees celsius and currently has datatype of Decimal(38,15), meaning up to 23 digits to the left of the decimal. While temperature is likely to have more of an impact on our analysis, we do not need more than 2 digits to the left of the decimal as temperatures are unlikely to go above 40 or 50, let alone 100. We will reduce this to Decimal(10,8) to retain precision 8 digits after the decimal point.
# * 'precipitation' - is total precipitation measured in meters. As the max value is less than 1, and the rest of the measurements are all in the tens to hundreds range, we will change the unit to millimeters and the type to Float32. This will reduce the number of decimal points we are dealing with, and also put it on a similar scale as the rest of the measurements.
# * 'surface_net_solar_radiation' - is the amount of solar radiation that reaches a horizontal plane at the surface of the Earth minus the amount reflected by the earth's surface. This is measured in Joules (J) per square meter (m^-2).
# * 'surface_solar_radiation_downwards' - is the amount of solar radiation that reaches a horizontal plane at the surface of the Earth. This is measured in Joules (J) per square meter (m^-2).
#
#
# https://confluence.ecmwf.int/display/CKB/ERA5%3A+data+documentation
#
# ---

# %% [markdown]
# ##### Testing Implementation of Changes

# %% [markdown]
# Similar to what was done with the customers data table, we will now implement the changes mentioned.

# %%
# We will change the location to two separate columns for longitude and latitude
# We will also convert the 'city' column to a categorical data type for better memory efficiency.
# We will then drop the unnecessary columns, and save the DataFrame to a new Parquet file()

# We'll also monitor the memory usage and time taken for this operation
# Start memory tracing
proc = psutil.Process()
mem_before = proc.memory_info().rss
tracemalloc.start()
# Start timing the conversion
t0 = time.perf_counter()

weather_lazy_operations = (
    pl.scan_parquet(weather_path)
    .with_columns([
        # converting timestamp to UTC timezone
        pl.col("timestamp").dt.replace_time_zone("UTC"),

        # converting to two separate columns for longitude and latitude
        pl.col("location")
          .map_elements(lambda h: wkb_to_coords(h)[0], return_dtype=pl.Float64)
          .alias("weather_longitude"),

        pl.col("location")
          .map_elements(lambda h: wkb_to_coords(h)[1], return_dtype=pl.Float64)
          .alias("weather_latitude"),

        # converting 'city' column to categorical data type
        pl.col("city").cast(pl.Categorical),

        # converting wind direction & speed to float32
        pl.col("wind_direction").cast(pl.Float32),
        pl.col("wind_speed").cast(pl.Float32),

        # converting temperature to float32
        pl.col("temperature").cast(pl.Float32),

        # converting precipitation to float 32, then to mm
        (pl.col("precipitation").cast(pl.Float32) * 1000).alias("precipitation_mm"), # precimpitation is in m, converting to mm

        # converting surface net solar radiation to Float64, then kilo-watt-hours
        ((pl.col("surface_net_solar_radiation").cast(pl.Float64) / (60 * 60))/1000).alias("surface_net_solar_radiation_kwh"),  # converting from J/m^2 to kWh/m^2
        # converting surface solar radiation downwards to Float64, then kilo-watt-hours
        ((pl.col("surface_solar_radiation_downwards").cast(pl.Float64) / (60 * 60))/1000).alias("surface_solar_radiation_downwards_kwh"),  # converting from J/m^2 to kWh/m^2
    ])
    .drop("location", "precipitation", "surface_net_solar_radiation", "surface_solar_radiation_downwards")  # drop the original versions of changed columns
    .with_columns(
        # convert to Asia/Kolkata timezone
        pl.col("timestamp").dt.replace_time_zone("Asia/Kolkata"),
))
weather_table_optimised_pldf = weather_lazy_operations.collect()

# Stop timer and memory tracing
t1 = time.perf_counter()
current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()
mem_after = proc.memory_info().rss

# Return stats
print(f"Time taken to optimise weather data: {t1 - t0:.2f} seconds")
print(f"PyObject Memory usage [tracemalloc]: {current / (1024 * 1024):.2f} MB (peak: {peak / (1024 * 1024):.2f} MB)")
print(f"Total Physical Memory usage (RSS) [psutil]: {(mem_after - mem_before) / (2**20):.3f} MB")
# Out:
# Time taken to optimise weather data: 151.70 seconds
# PyObject Memory usage [tracemalloc]: 0.01 MB (peak: 0.03 MB)
# Total Physical Memory usage (RSS) [psutil]: 976.547 MB

# %%
base, ext = os.path.splitext(weather_path)
weather_table_optimised_path = f"{base}_optimised{ext}"

# Save the modified DataFrame to a new Parquet file
weather_table_optimised_pldf.write_parquet(
    weather_table_optimised_path,
    compression="snappy",  # Using snappy compression for better performance
    statistics=True,  # Enable statistics for better query performance (doesn't make a noticeable change on disk storage)
)

# %%
dataframe_summary(weather_table_pldf, name="Original Weather Table", filepath=weather_path)
dataframe_summary(weather_table_optimised_pldf, name="Optimized Weather Table", filepath=weather_table_optimised_path)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# DataFrame Summary — Original Weather Table
# ------------------------------------------------------------------------------------------------------------------------
#
# File size on disk: 77.77 MB
#
# Estimated size in memory: 610.27 MB
#
# Per-column memory usage:
# ------------------------------------------------------------------------------------------------------------------------
#   • location        190.24 MB  ( 31.2%)
#   • wind_speed       61.35 MB  ( 10.1%)
#   • wind_direction   61.35 MB  ( 10.1%)
#   • temperature      61.35 MB  ( 10.1%)
#   • precipitation    61.35 MB  ( 10.1%)
#   • surface_net_solar_radiation  61.35 MB  ( 10.1%)
#   • surface_solar_radiation_downwards  61.35 MB  ( 10.1%)
#   • timestamp        30.44 MB  (  5.0%)
#   • city             21.47 MB  (  3.5%)
#
# Schema:
# ------------------------------------------------------------------------------------------------------------------------
#   • timestamp: Datetime(time_unit='us', time_zone=None)
#   • wind_speed: Decimal(precision=38, scale=18)
#   • wind_direction: Decimal(precision=38, scale=20)
#   • temperature: Decimal(precision=38, scale=15)
#   • city: String
#   • precipitation: Decimal(precision=38, scale=28)
#   • location: String
#   • surface_net_solar_radiation: Decimal(precision=38, scale=17)
#   • surface_solar_radiation_downwards: Decimal(precision=38, scale=17)
#
# First 5 rows:
# ------------------------------------------------------------------------------------------------------------------------
# shape: (5, 8)
# ┌────────────┬────────────┬────────────┬────────────┬───────┬────────────┬────────────┬────────────┐
# │ timestamp  ┆ wind_speed ┆ wind_direc ┆ temperatur ┆ city  ┆ precipitat ┆ surface_ne ┆ surface_so │
# │ ---        ┆ ---        ┆ tion       ┆ e          ┆ ---   ┆ ion        ┆ t_solar_ra ┆ lar_radiat │
# │ datetime[μ ┆ decimal[38 ┆ ---        ┆ ---        ┆ str   ┆ ---        ┆ diation    ┆ ion_downwa │
# │ s]         ┆ ,18]       ┆ decimal[38 ┆ decimal[38 ┆       ┆ decimal[38 ┆ ---        ┆ …          │
# │            ┆            ┆ ,20]       ┆ ,15]       ┆       ┆ ,28]       ┆ decimal[38 ┆ ---        │
# │            ┆            ┆            ┆            ┆       ┆            ┆ ,17]       ┆ decimal[38 │
# │            ┆            ┆            ┆            ┆       ┆            ┆            ┆ ,17]       │
# ╞════════════╪════════════╪════════════╪════════════╪═══════╪════════════╪════════════╪════════════╡
# │ 2024-12-13 ┆ 8.01357502 ┆ 105.092318 ┆ 15.9752197 ┆ delhi ┆ 0.00000000 ┆ 12296608.0 ┆ 14926616.0 │
# │ 13:00:00   ┆ 0999754000 ┆ 1186646500 ┆ 26562500   ┆       ┆ 0000000000 ┆ 0000000000 ┆ 0000000000 │
# │            ┆            ┆ 0000       ┆            ┆       ┆ 0000000000 ┆ 000000     ┆ 000000     │
# │ 2024-12-13 ┆ 8.28988395 ┆ 110.726143 ┆ 14.6460266 ┆ delhi ┆ 0.00000000 ┆ 12108108.0 ┆ 14736050.0 │
# │ 14:00:00   ┆ 7905610000 ┆ 2753614100 ┆ 11328125   ┆       ┆ 0000000000 ┆ 0000000000 ┆ 0000000000 │
# │            ┆            ┆ 0000       ┆            ┆       ┆ 0000000000 ┆ 000000     ┆ 000000     │
# │ 2024-12-13 ┆ 8.33689095 ┆ 110.277251 ┆ 14.6292419 ┆ delhi ┆ 0.00000000 ┆ 12149601.0 ┆ 14737817.0 │
# │ 14:00:00   ┆ 4411203000 ┆ 0258955400 ┆ 43359375   ┆       ┆ 0000000000 ┆ 0000000000 ┆ 0000000000 │
# │            ┆            ┆ 0000       ┆            ┆       ┆ 0000000000 ┆ 000000     ┆ 000000     │
# │ 2024-12-13 ┆ 8.40372646 ┆ 109.706665 ┆ 14.6237792 ┆ delhi ┆ 0.00000000 ┆ 12240716.0 ┆ 14738703.0 │
# │ 14:00:00   ┆ 8287198000 ┆ 5665699800 ┆ 96875000   ┆       ┆ 0000000000 ┆ 0000000000 ┆ 0000000000 │
# │            ┆            ┆ 0000       ┆            ┆       ┆ 0000000000 ┆ 000000     ┆ 000000     │
# │ 2024-12-13 ┆ 8.45463719 ┆ 109.043528 ┆ 14.6112976 ┆ delhi ┆ 0.00000000 ┆ 12278334.0 ┆ 14740205.0 │
# │ 14:00:00   ┆ 0808407000 ┆ 2144605200 ┆ 07421875   ┆       ┆ 0000000000 ┆ 0000000000 ┆ 0000000000 │
# │            ┆            ┆ 0000       ┆            ┆       ┆ 0000000000 ┆ 000000     ┆ 000000     │
# └────────────┴────────────┴────────────┴────────────┴───────┴────────────┴────────────┴────────────┘
# Note: id and location related columns are redacted here to preserve customer confidentiality
#
# ------------------------------------------------------------------------------------------------------------------------
# DataFrame Summary — Optimized Weather Table
# ------------------------------------------------------------------------------------------------------------------------
#
# File size on disk: 55.57 MB
#
# Estimated size in memory: 231.14 MB
#
# Per-column memory usage:
# ------------------------------------------------------------------------------------------------------------------------
#   • surface_net_solar_radiation_kwh  30.91 MB  ( 13.4%)
#   • surface_solar_radiation_downwards_kwh  30.91 MB  ( 13.4%)
#   • timestamp        30.44 MB  ( 13.2%)
#   • weather_longitude  30.44 MB  ( 13.2%)
#   • weather_latitude  30.44 MB  ( 13.2%)
#   • wind_speed       15.69 MB  (  6.8%)
#   • wind_direction   15.69 MB  (  6.8%)
#   • temperature      15.69 MB  (  6.8%)
#   • precipitation_mm  15.69 MB  (  6.8%)
#   • city             15.22 MB  (  6.6%)
#
# Schema:
# ------------------------------------------------------------------------------------------------------------------------
#   • timestamp: Datetime(time_unit='us', time_zone='Asia/Kolkata')
#   • wind_speed: Float32
#   • wind_direction: Float32
#   • temperature: Float32
#   • city: Categorical(ordering='physical')
#   • weather_longitude: Float64
#   • weather_latitude: Float64
#   • precipitation_mm: Float32
#   • surface_net_solar_radiation_kwh: Float64
#   • surface_solar_radiation_downwards_kwh: Float64
#
# First 5 rows:
# ------------------------------------------------------------------------------------------------------------------------
# shape: (5, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ timestamp ┆ wind_spee ┆ wind_dire ┆ temperatu ┆ … ┆ weather_l ┆ precipita ┆ surface_n ┆ surface_ │
# │ ---       ┆ d         ┆ ction     ┆ re        ┆   ┆ atitude   ┆ tion_mm   ┆ et_solar_ ┆ solar_ra │
# │ datetime[ ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ radiation ┆ diation_ │
# │ μs, Asia/ ┆ f32       ┆ f32       ┆ f32       ┆   ┆ f64       ┆ f32       ┆ _kw…      ┆ downwa…  │
# │ Kolkata]  ┆           ┆           ┆           ┆   ┆           ┆           ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2024-12-1 ┆ 8.013575  ┆ 105.09231 ┆ 15.97522  ┆ … ┆ 28.4      ┆ 0.0       ┆ 3.415724  ┆ 4.146282 │
# │ 3         ┆           ┆ 6         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 13:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ IST       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-12-1 ┆ 8.289884  ┆ 110.72614 ┆ 14.646027 ┆ … ┆ 28.8      ┆ 0.0       ┆ 3.363363  ┆ 4.093347 │
# │ 3         ┆           ┆ 3         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 14:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ IST       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-12-1 ┆ 8.336891  ┆ 110.27725 ┆ 14.629242 ┆ … ┆ 28.8      ┆ 0.0       ┆ 3.374889  ┆ 4.093838 │
# │ 3         ┆           ┆ 2         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 14:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ IST       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-12-1 ┆ 8.403727  ┆ 109.70666 ┆ 14.623779 ┆ … ┆ 28.8      ┆ 0.0       ┆ 3.400199  ┆ 4.094084 │
# │ 3         ┆           ┆ 5         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 14:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ IST       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-12-1 ┆ 8.454638  ┆ 109.04352 ┆ 14.611298 ┆ … ┆ 28.8      ┆ 0.0       ┆ 3.410648  ┆ 4.094501 │
# │ 3         ┆           ┆ 6         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 14:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ IST       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
# Note: id and location related columns are redacted here to preserve customer confidentiality

# %% [markdown]
# As we can see, both the file size on disk and the file size in memory has been reduced by these changes.

# %%
# removing the temporary files created during the process
try:
    os.remove(weather_table_optimised_path)
    print(f"Successfully deleted: {weather_table_optimised_path}")
except FileNotFoundError:
    print(f"File does not exist: {weather_table_optimised_path}")
# Out:
# Successfully deleted: ../../data/hitachi/weather_20250714_1401_optimised.parquet

# %% [markdown]
# #### Grid readings table [grid_readings_table_pldf]

# %%
# Loading the data
grid_readings_table_pldf = pl.read_parquet(grid_readings_path)

# %%
dataframe_summary(grid_readings_table_pldf, name="Grid Readings Table", filepath=grid_readings_path)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# DataFrame Summary — Grid Readings Table
# ------------------------------------------------------------------------------------------------------------------------
#
# File size on disk: 21.71 MB
#
# Estimated size in memory: 51.37 MB
#
# Per-column memory usage:
# ------------------------------------------------------------------------------------------------------------------------
#   • timestamp         4.28 MB  (  8.3%)
#   • thermal_generation   4.28 MB  (  8.3%)
#   • gas_generation    4.28 MB  (  8.3%)
#   • g_co2_per_kwh     4.28 MB  (  8.3%)
#   • hydro_generation   4.28 MB  (  8.3%)
#   • nuclear_generation   4.28 MB  (  8.3%)
#   • renewable_generation   4.28 MB  (  8.3%)
#   • tons_co2          4.28 MB  (  8.3%)
#   • total_generation   4.28 MB  (  8.3%)
#   • tons_co2_per_mwh   4.28 MB  (  8.3%)
#   • demand_met        4.28 MB  (  8.3%)
#   • net_demand        4.28 MB  (  8.3%)
#
# Schema:
# ------------------------------------------------------------------------------------------------------------------------
#   • timestamp: Datetime(time_unit='us', time_zone=None)
#   • thermal_generation: Float64
#   • gas_generation: Float64
#   • g_co2_per_kwh: Float64
#   • hydro_generation: Float64
#   • nuclear_generation: Float64
#   • renewable_generation: Float64
#   • tons_co2: Float64
#   • total_generation: Float64
#   • tons_co2_per_mwh: Float64
#   • demand_met: Float64
#   • net_demand: Float64
#
# First 5 rows:
# ------------------------------------------------------------------------------------------------------------------------
# shape: (5, 12)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ timestamp ┆ thermal_g ┆ gas_gener ┆ g_co2_per ┆ … ┆ total_gen ┆ tons_co2_ ┆ demand_me ┆ net_dema │
# │ ---       ┆ eneration ┆ ation     ┆ _kwh      ┆   ┆ eration   ┆ per_mwh   ┆ t         ┆ nd       │
# │ datetime[ ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ μs]       ┆ f64       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2022-01-0 ┆ 136202.0  ┆ 2901.0    ┆ 815.57308 ┆ … ┆ 164327.0  ┆ 0.815573  ┆ 162948.0  ┆ 154427.0 │
# │ 4         ┆           ┆           ┆ 8         ┆   ┆           ┆           ┆           ┆          │
# │ 17:05:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2022-01-0 ┆ 136202.0  ┆ 2901.0    ┆ 815.57308 ┆ … ┆ 164327.0  ┆ 0.815573  ┆ 162948.0  ┆ 154427.0 │
# │ 4         ┆           ┆           ┆ 8         ┆   ┆           ┆           ┆           ┆          │
# │ 17:10:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2022-01-0 ┆ 136202.0  ┆ 2901.0    ┆ 815.57308 ┆ … ┆ 164327.0  ┆ 0.815573  ┆ 162948.0  ┆ 154427.0 │
# │ 4         ┆           ┆           ┆ 8         ┆   ┆           ┆           ┆           ┆          │
# │ 17:15:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2022-01-0 ┆ 136202.0  ┆ 2901.0    ┆ 815.57308 ┆ … ┆ 164327.0  ┆ 0.815573  ┆ 162948.0  ┆ 154427.0 │
# │ 4         ┆           ┆           ┆ 8         ┆   ┆           ┆           ┆           ┆          │
# │ 17:20:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2022-01-0 ┆ 136202.0  ┆ 2901.0    ┆ 815.57308 ┆ … ┆ 164327.0  ┆ 0.815573  ┆ 162948.0  ┆ 154427.0 │
# │ 4         ┆           ┆           ┆ 8         ┆   ┆           ┆           ┆           ┆          │
# │ 17:25:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
# Note: id and location related columns are redacted here to preserve customer confidentiality

# %% [markdown]
# We could potentially downcast some of these larger-valued columns to float32, but at this point we might as well leave them. They are not taking up very much space in memory or in disk at all and will take up even less after aggregated to the hourly level.

# %% [markdown]
# #### Meter Readings Datasets

# %% [markdown]
# ##### Large Meter Readings Dataset [meter_readings_2021_pldf]

# %%
# Loading the data
meter_readings_2021_pldf = pl.read_parquet(meter_readings_2021_path)

# %%
dataframe_summary(meter_readings_2021_pldf, name="Meter Readings Table (2021)", filepath=meter_readings_2021_path)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# DataFrame Summary — Meter Readings Table (2021)
# ------------------------------------------------------------------------------------------------------------------------
#
# File size on disk: 2,080.60 MB
#
# Estimated size in memory: 9,277.18 MB
#
# Per-column memory usage:
# ------------------------------------------------------------------------------------------------------------------------
#   • date            4406.66 MB  ( 47.5%)
#   • ca_id           1855.44 MB  ( 20.0%)
#   • value           1855.44 MB  ( 20.0%)
#   • city            1159.65 MB  ( 12.5%)
#
# Schema:
# ------------------------------------------------------------------------------------------------------------------------
#   • ca_id: Int64
#   • date: String
#   • value: Float64
#   • city: String
#
# First 5 rows:
# ------------------------------------------------------------------------------------------------------------------------
# shape: (5, 2)
# ┌─────────────────────┬───────┐
# │ date                ┆ city  │
# │ ---                 ┆ ---   │
# │ str                 ┆ str   │
# ╞═════════════════════╪═══════╡
# │ 2021-12-01 00:00:00 ┆ delhi │
# │ 2021-12-01 00:00:00 ┆ delhi │
# │ 2021-12-01 00:00:00 ┆ delhi │
# │ 2021-12-01 00:00:00 ┆ delhi │
# │ 2021-12-01 00:00:00 ┆ delhi │
# └─────────────────────┴───────┘
# Note: id and location related columns are redacted here to preserve customer confidentiality

# %%
# Lets change date to datetime, ca_id to string, and city to categorical

meter_readings_2021_lazy_operations = (
    pl.scan_parquet(meter_readings_2021_path)
    .with_columns([
    # converting 'date' column to datetime YYYY-MM-DD HH:MM:SS and setting timezone to Asia/Kolkata
        (pl.col("date").str.strptime(pl.Datetime, "%Y-%m-%d %H:%M:%S")).dt.replace_time_zone("Asia/Kolkata"),
        # converting 'ca_id' column to string
        pl.col("ca_id").cast(pl.String),
        # converting 'city' column to categorical
        pl.col("city").cast(pl.Categorical),
    ])
)
meter_readings_2021_optimised_pldf = meter_readings_2021_lazy_operations.collect()

# Save the modified DataFrame to a new Parquet file
base, ext = os.path.splitext(meter_readings_2021_path)
meter_readings_2021_optimised_path = f"{base}_optimised{ext}"

meter_readings_2021_optimised_pldf.write_parquet(
    meter_readings_2021_optimised_path,
    compression="snappy",  # Using snappy compression for better performance
    statistics=True,  # Enable statistics for better query performance (doesn't make a huge impact on disk storage)
)

dataframe_summary(meter_readings_2021_pldf, name="Original Meter Readings Table (2021)", filepath=meter_readings_2021_path)
dataframe_summary(meter_readings_2021_optimised_pldf, name="Optimized Meter Readings Table (2021)", filepath=meter_readings_2021_optimised_path)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# DataFrame Summary — Original Meter Readings Table (2021)
# ------------------------------------------------------------------------------------------------------------------------
#
# File size on disk: 2,080.60 MB
#
# Estimated size in memory: 9,277.18 MB
#
# Per-column memory usage:
# ------------------------------------------------------------------------------------------------------------------------
#   • date            4406.66 MB  ( 47.5%)
#   • ca_id           1855.44 MB  ( 20.0%)
#   • value           1855.44 MB  ( 20.0%)
#   • city            1159.65 MB  ( 12.5%)
#
# Schema:
# ------------------------------------------------------------------------------------------------------------------------
#   • ca_id: Int64
#   • date: String
#   • value: Float64
#   • city: String
#
# First 5 rows:
# ------------------------------------------------------------------------------------------------------------------------
# shape: (5, 2)
# ┌─────────────────────┬───────┐
# │ date                ┆ city  │
# │ ---                 ┆ ---   │
# │ str                 ┆ str   │
# ╞═════════════════════╪═══════╡
# │ 2021-12-01 00:00:00 ┆ delhi │
# │ 2021-12-01 00:00:00 ┆ delhi │
# │ 2021-12-01 00:00:00 ┆ delhi │
# │ 2021-12-01 00:00:00 ┆ delhi │
# │ 2021-12-01 00:00:00 ┆ delhi │
# └─────────────────────┴───────┘
# Note: id and location related columns are redacted here to preserve customer confidentiality
#
# ------------------------------------------------------------------------------------------------------------------------
# DataFrame Summary — Optimized Meter Readings Table (2021)
# ------------------------------------------------------------------------------------------------------------------------
#
# File size on disk: 2,414.18 MB
#
# Estimated size in memory: 7,189.82 MB
#
# Per-column memory usage:
# ------------------------------------------------------------------------------------------------------------------------
#   • ca_id           2551.23 MB  ( 35.5%)
#   • date            1855.44 MB  ( 25.8%)
#   • value           1855.44 MB  ( 25.8%)
#   • city            927.72 MB  ( 12.9%)
#
# Schema:
# ------------------------------------------------------------------------------------------------------------------------
#   • ca_id: String
#   • date: Datetime(time_unit='us', time_zone='Asia/Kolkata')
#   • value: Float64
#   • city: Categorical(ordering='physical')
#
# First 5 rows:
# ------------------------------------------------------------------------------------------------------------------------
# shape: (5, 2)
# ┌────────────────────────────┬───────┐
# │ date                       ┆ city  │
# │ ---                        ┆ ---   │
# │ datetime[μs, Asia/Kolkata] ┆ cat   │
# ╞════════════════════════════╪═══════╡
# │ 2021-12-01 00:00:00 IST    ┆ delhi │
# │ 2021-12-01 00:00:00 IST    ┆ delhi │
# │ 2021-12-01 00:00:00 IST    ┆ delhi │
# │ 2021-12-01 00:00:00 IST    ┆ delhi │
# │ 2021-12-01 00:00:00 IST    ┆ delhi │
# └────────────────────────────┴───────┘
# Note: id and location related columns are redacted here to preserve customer confidentiality

# %% [markdown]
# We may have increased the size of the file on disk, but we have reduced the size in memory.
# Additionally, the file should be easier and quicker to query with the statistics saving enabled on polars.
#
# Though the ca_id column increased significantly in size, we are now using string format instead of integer, which is recommended for ids.

# %%
# Removing the temporary files created during the process
try:
    os.remove(meter_readings_2021_optimised_path)
    print(f"Successfully deleted: {meter_readings_2021_optimised_path}")
except FileNotFoundError:
    print(f"File does not exist: {meter_readings_2021_optimised_path}")
# Out:
# Successfully deleted: ../../data/hitachi/meter_primary_files/meter_readings_2021_20250714_2015_optimised.parquet

# %% [markdown]
# ## *Summary*

# %% [markdown]
# **KEY TAKEAWAYS:**
# * Use parquet files instead of csv files
# * Use snappy compression for better performance
# * Save the file with statistics enabled to allow for faster queries
# * Use polars' lazy execution for better performance with large datasets
# * Use the correct data types for each column to reduce memory usage
#
# **Related changes:**
# * Make sure to convert timestamps to the correct timezone
# * Change city column to categorical datatype
# * Change location column to two separate columns for longitude and latitude
# * Change wind_direction, wind_speed, and temperature to float32
# * Change precipitation to millimeters and float32
# * Change solar radiation fields to kWh/m^2 and float32
